# %%
import pandas as pd

# %%
data = pd.read_csv("./artist_data_summary.csv")

# %%
data
# Out:
#              artist  total_streams  total_daily  max_streams  song_count  \
# 0          Jay Sean      747533943       438514    747533943           1
# 1     House Of Pain      572420135       422147    572420135           1
# 2       Teddy Swims     1126280439      7082537   1126280439           1
# 3         Sam Cooke      577307100       395982    577307100           1
# 4     Zion & Lennox     2245922760       727793    932679414           3
# ..              ...            ...          ...          ...         ...
# 986          Pritam      548978194       311330    548978194           1
# 987      Neon Trees      881374639       342276    881374639           1
# 988  Sufjan Stevens      516641011       217461    516641011           1
# 989    Jordan Davis      512938783       572278    512938783           1
# 990        The Cure     1527840526       804098    766826698           2
#
#      average_streams  average_daily
# 0       7.475339e+08   4.385140e+05
# ...
